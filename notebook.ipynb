# %%
SELECT region, AVG(usd_value) AS avg_usd_value
FROM public.final_table
GROUP BY region
HAVING AVG(usd_value) > 40000
ORDER BY avg_usd_value
LIMIT 2;
# Out:
#    region  avg_usd_value
# 0    Asia   62083.333333
# 1  Europe   75350.000000

# %%
SELECT region, usd_value 
FROM public.final_table
WHERE region IN('Africa', 'Asia', 'Europe');
# Out:
#     region  usd_value
# 0   Africa      17000
# 1     Asia      48800
# 2   Europe      73600
# 3   Africa      16200
# 4     Asia      49600
# 5   Europe      76200
# 6   Africa      28600
# 7     Asia      63800
# 8   Europe      92000
# 9   Africa      34100
# 10    Asia      56300
# 11  Europe      79800
# 12  Africa      31200
# 13    Asia      74000
# 14  Europe      63500
# 15  Africa      33200
# 16    Asia      80000
# 17  Europe      67000

# %%
SELECT region, price
FROM public.prices
WHERE region = 'Europe' OR region = 'Africa';
# Out:
#     region  price
# 0   Europe    200
# 1   Europe    200
# 2   Europe    200
# 3   Europe    100
# 4   Europe    250
# 5   Europe    250
# 6   Africa    200
# 7   Africa    200
# 8   Africa    200
# 9   Africa    100
# 10  Africa    200
# 11  Africa    200

# %%
SELECT region, AVG(price) AS avg_price
FROM public.prices
GROUP BY region;
# Out:
#           region   avg_price
# 0  South America  183.333333
# 1        Oceania  200.000000
# 2         Africa  183.333333
# 3           Asia  183.333333
# 4  North America  200.000000
# 5         Europe  200.000000

# %%
SELECT * FROM public.dates
# Out:
#                          date                     month
# 0   2021-01-01 00:00:00+00:00 2021-01-01 00:00:00+00:00
# 1   2021-01-02 00:00:00+00:00 2021-01-01 00:00:00+00:00
# 2   2021-01-03 00:00:00+00:00 2021-01-01 00:00:00+00:00
# 3   2021-01-04 00:00:00+00:00 2021-01-01 00:00:00+00:00
# 4   2021-01-05 00:00:00+00:00 2021-01-01 00:00:00+00:00
# ..                        ...                       ...
# 725 2022-12-27 00:00:00+00:00 2022-12-01 00:00:00+00:00
# 726 2022-12-28 00:00:00+00:00 2022-12-01 00:00:00+00:00
# 727 2022-12-29 00:00:00+00:00 2022-12-01 00:00:00+00:00
# 728 2022-12-30 00:00:00+00:00 2022-12-01 00:00:00+00:00
# 729 2022-12-31 00:00:00+00:00 2022-12-01 00:00:00+00:00
#
# [730 rows x 2 columns]
